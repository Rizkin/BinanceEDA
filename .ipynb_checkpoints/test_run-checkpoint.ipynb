# %%
from connections.client import BinanceClient
from config.settings import BINANCE_API_KEY, BINANCE_SECRET_KEY, USE_TESTNET
from data.fetch import BinanceDataFetcher,BinanceOptionsFetcher
from datetime import datetime, timedelta

# %%
import importlib
import data.fetch  # Replace 'fetch' with the module name
importlib.reload(data.fetch)
import logging
import sys

# Remove all existing logging handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# Reconfigure logging
logging.basicConfig(
    level=logging.DEBUG,  # Set to DEBUG to capture all levels
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    stream=sys.stdout  # Direct logs to the console
)

logger = logging.getLogger(__name__)
logger.info("Logging system initialized.")  # Test log
# Out:
# 2024-12-30 17:39:41,901 - __main__ - INFO - Logging system initialized.

# %%
# Test settings
print("API Key:", BINANCE_API_KEY)
print("Testnet Mode:", USE_TESTNET)

# Test the BinanceClient
client = BinanceClient()
print(client.test_connection())

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
# Out:
# API Key: FdEFwUP7BbC4y4GshdHi3SuGaWUTmqABFUSD1J3tySAGxsxGAumA9zaeR5wYI9RVFdEFwUP7BbC4y4GshdHi3SuGaWUTmqABFUSD1J3tySAGxsxGAumA9zaeR5wYI9RV
# Testnet Mode: False
# 2024-12-30 17:39:41,909 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.binance.com:443
# 2024-12-30 17:39:42,170 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/ping HTTP/1.1" 200 2
# Initialized Binance Client (Testnet: False)
# 2024-12-30 17:39:42,437 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/ping HTTP/1.1" 200 2
# Connection successful: {}
# {}

# %%
import os
print(os.getcwd())
import sys
print(sys.path)
# Out:
# /home/ec2-user/BinanceEDA
# ['/usr/lib64/python39.zip', '/usr/lib64/python3.9', '/usr/lib64/python3.9/lib-dynload', '', '/home/ec2-user/.local/lib/python3.9/site-packages', '/home/ec2-user/BinanceEDA', '/usr/lib64/python3.9/site-packages', '/usr/lib/python3.9/site-packages']

# %%
# Initialize the data fetcher
fetcher = BinanceDataFetcher()

# Define parameters
symbol = "BTCUSDT"  # Trading pair
interval = "15m"  # intervals here
start_days_ago = 1800  # Start time: 1 day ago
end_days_ago = 0  # End time: now

# Create a dynamic output file name
output_file = f"{symbol}_{interval}_day{start_days_ago}_day{end_days_ago}.csv"

# Print the dynamic file name to verify
print(f"Output file name: {output_file}")


try:
    # Calculate start and end timestamps
    start_time = datetime.now() - timedelta(days=start_days_ago)
    end_time = datetime.now() - timedelta(days=end_days_ago)

    # Log the calculated timestamps
    print(f"Start Time: {start_time} ({int(start_time.timestamp() * 1000)} ms)")
    print(f"End Time: {end_time} ({int(end_time.timestamp() * 1000)} ms)")

    # Fetch and save data
    fetcher.fetch_and_save_historical_data(
        symbol=symbol,
        interval=interval,
        start_days_ago=start_days_ago,
        end_days_ago=end_days_ago,
        output_file=output_file
    )

    print(f"Data successfully saved to {output_file}")

except OverflowError as oe:
    print(f"OverflowError occurred: {oe}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# 2024-12-30 17:41:12,965 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.binance.com:443
# 2024-12-30 17:41:13,231 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/ping HTTP/1.1" 200 2
# Initialized Binance Client (Testnet: False)
# Output file name: BTCUSDT_15m_day730_day0.csv
# Start Time: 2022-12-31 17:41:13.233589 (1672508473233 ms)
# End Time: 2024-12-30 17:41:13.233595 (1735580473233 ms)
# 2024-12-30 17:41:13,233 - data.fetch - INFO - Fetching historical data for BTCUSDT from 2022-12-31 17:41:13.233000 to 2024-12-30 17:41:13.233000 with 15m interval.
# 2024-12-30 17:41:13,234 - data.fetch - INFO - Fetching data from 2022-12-31 17:41:13.233000 to 2023-01-11 03:41:13.233000.
# 2024-12-30 17:41:13,235 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1672508473233, endTime 1673408473233, limit 1000.
# 2024-12-30 17:41:13,503 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1673408473233&interval=15m&limit=1000&startTime=1672508473233&symbol=BTCUSDT HTTP/1.1" 200 56411
# 2024-12-30 17:41:13,850 - data.fetch - INFO - Fetching data from 2023-01-11 03:30:00.001000 to 2023-01-21 13:30:00.001000.
# 2024-12-30 17:41:13,851 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1673407800001, endTime 1674307800001, limit 1000.
# 2024-12-30 17:41:14,115 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1674307800001&interval=15m&limit=1000&startTime=1673407800001&symbol=BTCUSDT HTTP/1.1" 200 58634
# 2024-12-30 17:41:14,223 - data.fetch - INFO - Fetching data from 2023-01-21 13:30:00.001000 to 2023-01-31 23:30:00.001000.
# 2024-12-30 17:41:14,224 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1674307800001, endTime 1675207800001, limit 1000.
# 2024-12-30 17:41:14,489 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1675207800001&interval=15m&limit=1000&startTime=1674307800001&symbol=BTCUSDT HTTP/1.1" 200 58281
# 2024-12-30 17:41:14,595 - data.fetch - INFO - Fetching data from 2023-01-31 23:30:00.001000 to 2023-02-11 09:30:00.001000.
# 2024-12-30 17:41:14,596 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1675207800001, endTime 1676107800001, limit 1000.
# 2024-12-30 17:41:14,859 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1676107800001&interval=15m&limit=1000&startTime=1675207800001&symbol=BTCUSDT HTTP/1.1" 200 58265
# 2024-12-30 17:41:14,964 - data.fetch - INFO - Fetching data from 2023-02-11 09:30:00.001000 to 2023-02-21 19:30:00.001000.
# 2024-12-30 17:41:14,965 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1676107800001, endTime 1677007800001, limit 1000.
# 2024-12-30 17:41:15,232 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1677007800001&interval=15m&limit=1000&startTime=1676107800001&symbol=BTCUSDT HTTP/1.1" 200 58498
# 2024-12-30 17:41:15,337 - data.fetch - INFO - Fetching data from 2023-02-21 19:30:00.001000 to 2023-03-04 05:30:00.001000.
# 2024-12-30 17:41:15,338 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1677007800001, endTime 1677907800001, limit 1000.
# 2024-12-30 17:41:15,603 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1677907800001&interval=15m&limit=1000&startTime=1677007800001&symbol=BTCUSDT HTTP/1.1" 200 58435
# 2024-12-30 17:41:15,715 - data.fetch - INFO - Fetching data from 2023-03-04 05:30:00.001000 to 2023-03-14 15:30:00.001000.
# 2024-12-30 17:41:15,716 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1677907800001, endTime 1678807800001, limit 1000.
# 2024-12-30 17:41:15,983 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1678807800001&interval=15m&limit=1000&startTime=1677907800001&symbol=BTCUSDT HTTP/1.1" 200 58644
# 2024-12-30 17:41:16,088 - data.fetch - INFO - Fetching data from 2023-03-14 15:30:00.001000 to 2023-03-25 01:30:00.001000.
# 2024-12-30 17:41:16,089 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1678807800001, endTime 1679707800001, limit 1000.
# 2024-12-30 17:41:16,357 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1679707800001&interval=15m&limit=1000&startTime=1678807800001&symbol=BTCUSDT HTTP/1.1" 200 58629
# 2024-12-30 17:41:16,462 - data.fetch - INFO - Fetching data from 2023-03-25 01:30:00.001000 to 2023-04-04 11:30:00.001000.
# 2024-12-30 17:41:16,463 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1679707800001, endTime 1680607800001, limit 1000.
# 2024-12-30 17:41:16,729 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1680607800001&interval=15m&limit=1000&startTime=1679707800001&symbol=BTCUSDT HTTP/1.1" 200 56354
# 2024-12-30 17:41:16,834 - data.fetch - INFO - Fetching data from 2023-04-04 11:30:00.001000 to 2023-04-14 21:30:00.001000.
# 2024-12-30 17:41:16,835 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1680607800001, endTime 1681507800001, limit 1000.
# 2024-12-30 17:41:17,105 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1681507800001&interval=15m&limit=1000&startTime=1680607800001&symbol=BTCUSDT HTTP/1.1" 200 55662
# 2024-12-30 17:41:17,211 - data.fetch - INFO - Fetching data from 2023-04-14 21:30:00.001000 to 2023-04-25 07:30:00.001000.
# 2024-12-30 17:41:17,212 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1681507800001, endTime 1682407800001, limit 1000.
# 2024-12-30 17:41:17,477 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1682407800001&interval=15m&limit=1000&startTime=1681507800001&symbol=BTCUSDT HTTP/1.1" 200 55838
# 2024-12-30 17:41:17,583 - data.fetch - INFO - Fetching data from 2023-04-25 07:30:00.001000 to 2023-05-05 17:30:00.001000.
# 2024-12-30 17:41:17,584 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1682407800001, endTime 1683307800001, limit 1000.
# 2024-12-30 17:41:17,850 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1683307800001&interval=15m&limit=1000&startTime=1682407800001&symbol=BTCUSDT HTTP/1.1" 200 56296
# 2024-12-30 17:41:17,955 - data.fetch - INFO - Fetching data from 2023-05-05 17:30:00.001000 to 2023-05-16 03:30:00.001000.
# 2024-12-30 17:41:17,956 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1683307800001, endTime 1684207800001, limit 1000.
# 2024-12-30 17:41:18,223 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1684207800001&interval=15m&limit=1000&startTime=1683307800001&symbol=BTCUSDT HTTP/1.1" 200 55750
# 2024-12-30 17:41:18,328 - data.fetch - INFO - Fetching data from 2023-05-16 03:30:00.001000 to 2023-05-26 13:30:00.001000.
# 2024-12-30 17:41:18,329 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1684207800001, endTime 1685107800001, limit 1000.
# 2024-12-30 17:41:18,594 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1685107800001&interval=15m&limit=1000&startTime=1684207800001&symbol=BTCUSDT HTTP/1.1" 200 55068
# 2024-12-30 17:41:18,701 - data.fetch - INFO - Fetching data from 2023-05-26 13:30:00.001000 to 2023-06-05 23:30:00.001000.
# 2024-12-30 17:41:18,701 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1685107800001, endTime 1686007800001, limit 1000.
# 2024-12-30 17:41:18,967 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1686007800001&interval=15m&limit=1000&startTime=1685107800001&symbol=BTCUSDT HTTP/1.1" 200 55074
# 2024-12-30 17:41:19,074 - data.fetch - INFO - Fetching data from 2023-06-05 23:30:00.001000 to 2023-06-16 09:30:00.001000.
# 2024-12-30 17:41:19,075 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1686007800001, endTime 1686907800001, limit 1000.
# 2024-12-30 17:41:19,341 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1686907800001&interval=15m&limit=1000&startTime=1686007800001&symbol=BTCUSDT HTTP/1.1" 200 55566
# 2024-12-30 17:41:19,446 - data.fetch - INFO - Fetching data from 2023-06-16 09:30:00.001000 to 2023-06-26 19:30:00.001000.
# 2024-12-30 17:41:19,447 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1686907800001, endTime 1687807800001, limit 1000.
# 2024-12-30 17:41:19,714 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1687807800001&interval=15m&limit=1000&startTime=1686907800001&symbol=BTCUSDT HTTP/1.1" 200 55595
# 2024-12-30 17:41:19,819 - data.fetch - INFO - Fetching data from 2023-06-26 19:30:00.001000 to 2023-07-07 05:30:00.001000.
# 2024-12-30 17:41:19,820 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1687807800001, endTime 1688707800001, limit 1000.
# 2024-12-30 17:41:20,087 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1688707800001&interval=15m&limit=1000&startTime=1687807800001&symbol=BTCUSDT HTTP/1.1" 200 55266
# 2024-12-30 17:41:20,194 - data.fetch - INFO - Fetching data from 2023-07-07 05:30:00.001000 to 2023-07-17 15:30:00.001000.
# 2024-12-30 17:41:20,195 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1688707800001, endTime 1689607800001, limit 1000.
# 2024-12-30 17:41:20,459 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1689607800001&interval=15m&limit=1000&startTime=1688707800001&symbol=BTCUSDT HTTP/1.1" 200 54384
# 2024-12-30 17:41:20,564 - data.fetch - INFO - Fetching data from 2023-07-17 15:30:00.001000 to 2023-07-28 01:30:00.001000.
# 2024-12-30 17:41:20,565 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1689607800001, endTime 1690507800001, limit 1000.
# 2024-12-30 17:41:20,831 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1690507800001&interval=15m&limit=1000&startTime=1689607800001&symbol=BTCUSDT HTTP/1.1" 200 54236
# 2024-12-30 17:41:20,936 - data.fetch - INFO - Fetching data from 2023-07-28 01:30:00.001000 to 2023-08-07 11:30:00.001000.
# 2024-12-30 17:41:20,937 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1690507800001, endTime 1691407800001, limit 1000.
# 2024-12-30 17:41:21,202 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1691407800001&interval=15m&limit=1000&startTime=1690507800001&symbol=BTCUSDT HTTP/1.1" 200 53652
# 2024-12-30 17:41:21,308 - data.fetch - INFO - Fetching data from 2023-08-07 11:30:00.001000 to 2023-08-17 21:30:00.001000.
# 2024-12-30 17:41:21,309 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1691407800001, endTime 1692307800001, limit 1000.
# 2024-12-30 17:41:21,572 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1692307800001&interval=15m&limit=1000&startTime=1691407800001&symbol=BTCUSDT HTTP/1.1" 200 53642
# 2024-12-30 17:41:21,678 - data.fetch - INFO - Fetching data from 2023-08-17 21:30:00.001000 to 2023-08-28 07:30:00.001000.
# 2024-12-30 17:41:21,679 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1692307800001, endTime 1693207800001, limit 1000.
# 2024-12-30 17:41:21,945 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1693207800001&interval=15m&limit=1000&startTime=1692307800001&symbol=BTCUSDT HTTP/1.1" 200 54154
# 2024-12-30 17:41:22,052 - data.fetch - INFO - Fetching data from 2023-08-28 07:30:00.001000 to 2023-09-07 17:30:00.001000.
# 2024-12-30 17:41:22,052 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1693207800001, endTime 1694107800001, limit 1000.
# 2024-12-30 17:41:22,316 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1694107800001&interval=15m&limit=1000&startTime=1693207800001&symbol=BTCUSDT HTTP/1.1" 200 54481
# 2024-12-30 17:41:22,421 - data.fetch - INFO - Fetching data from 2023-09-07 17:30:00.001000 to 2023-09-18 03:30:00.001000.
# 2024-12-30 17:41:22,422 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1694107800001, endTime 1695007800001, limit 1000.
# 2024-12-30 17:41:22,690 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1695007800001&interval=15m&limit=1000&startTime=1694107800001&symbol=BTCUSDT HTTP/1.1" 200 54253
# 2024-12-30 17:41:22,796 - data.fetch - INFO - Fetching data from 2023-09-18 03:30:00.001000 to 2023-09-28 13:30:00.001000.
# 2024-12-30 17:41:22,796 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1695007800001, endTime 1695907800001, limit 1000.
# 2024-12-30 17:41:23,061 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1695907800001&interval=15m&limit=1000&startTime=1695007800001&symbol=BTCUSDT HTTP/1.1" 200 54247
# 2024-12-30 17:41:23,166 - data.fetch - INFO - Fetching data from 2023-09-28 13:30:00.001000 to 2023-10-08 23:30:00.001000.
# 2024-12-30 17:41:23,167 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1695907800001, endTime 1696807800001, limit 1000.
# 2024-12-30 17:41:23,431 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1696807800001&interval=15m&limit=1000&startTime=1695907800001&symbol=BTCUSDT HTTP/1.1" 200 54690
# 2024-12-30 17:41:23,536 - data.fetch - INFO - Fetching data from 2023-10-08 23:30:00.001000 to 2023-10-19 09:30:00.001000.
# 2024-12-30 17:41:23,537 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1696807800001, endTime 1697707800001, limit 1000.
# 2024-12-30 17:41:23,803 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1697707800001&interval=15m&limit=1000&startTime=1696807800001&symbol=BTCUSDT HTTP/1.1" 200 54815
# 2024-12-30 17:41:23,908 - data.fetch - INFO - Fetching data from 2023-10-19 09:30:00.001000 to 2023-10-29 19:30:00.001000.
# 2024-12-30 17:41:23,909 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1697707800001, endTime 1698607800001, limit 1000.
# 2024-12-30 17:41:24,174 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1698607800001&interval=15m&limit=1000&startTime=1697707800001&symbol=BTCUSDT HTTP/1.1" 200 55950
# 2024-12-30 17:41:24,279 - data.fetch - INFO - Fetching data from 2023-10-29 19:30:00.001000 to 2023-11-09 05:30:00.001000.
# 2024-12-30 17:41:24,280 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1698607800001, endTime 1699507800001, limit 1000.
# 2024-12-30 17:41:24,553 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1699507800001&interval=15m&limit=1000&startTime=1698607800001&symbol=BTCUSDT HTTP/1.1" 200 55568
# 2024-12-30 17:41:24,658 - data.fetch - INFO - Fetching data from 2023-11-09 05:30:00.001000 to 2023-11-19 15:30:00.001000.
# 2024-12-30 17:41:24,659 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1699507800001, endTime 1700407800001, limit 1000.
# 2024-12-30 17:41:24,924 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1700407800001&interval=15m&limit=1000&startTime=1699507800001&symbol=BTCUSDT HTTP/1.1" 200 55653
# 2024-12-30 17:41:25,030 - data.fetch - INFO - Fetching data from 2023-11-19 15:30:00.001000 to 2023-11-30 01:30:00.001000.
# 2024-12-30 17:41:25,031 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1700407800001, endTime 1701307800001, limit 1000.
# 2024-12-30 17:41:25,296 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1701307800001&interval=15m&limit=1000&startTime=1700407800001&symbol=BTCUSDT HTTP/1.1" 200 55455
# 2024-12-30 17:41:25,403 - data.fetch - INFO - Fetching data from 2023-11-30 01:30:00.001000 to 2023-12-10 11:30:00.001000.
# 2024-12-30 17:41:25,404 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1701307800001, endTime 1702207800001, limit 1000.
# 2024-12-30 17:41:25,671 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1702207800001&interval=15m&limit=1000&startTime=1701307800001&symbol=BTCUSDT HTTP/1.1" 200 56069
# 2024-12-30 17:41:25,845 - data.fetch - INFO - Fetching data from 2023-12-10 11:30:00.001000 to 2023-12-20 21:30:00.001000.
# 2024-12-30 17:41:25,845 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1702207800001, endTime 1703107800001, limit 1000.
# 2024-12-30 17:41:26,110 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1703107800001&interval=15m&limit=1000&startTime=1702207800001&symbol=BTCUSDT HTTP/1.1" 200 56302
# 2024-12-30 17:41:26,216 - data.fetch - INFO - Fetching data from 2023-12-20 21:30:00.001000 to 2023-12-31 07:30:00.001000.
# 2024-12-30 17:41:26,217 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1703107800001, endTime 1704007800001, limit 1000.
# 2024-12-30 17:41:26,484 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1704007800001&interval=15m&limit=1000&startTime=1703107800001&symbol=BTCUSDT HTTP/1.1" 200 55522
# 2024-12-30 17:41:26,590 - data.fetch - INFO - Fetching data from 2023-12-31 07:30:00.001000 to 2024-01-10 17:30:00.001000.
# 2024-12-30 17:41:26,591 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1704007800001, endTime 1704907800001, limit 1000.
# 2024-12-30 17:41:26,859 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1704907800001&interval=15m&limit=1000&startTime=1704007800001&symbol=BTCUSDT HTTP/1.1" 200 56525
# 2024-12-30 17:41:26,964 - data.fetch - INFO - Fetching data from 2024-01-10 17:30:00.001000 to 2024-01-21 03:30:00.001000.
# 2024-12-30 17:41:26,965 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1704907800001, endTime 1705807800001, limit 1000.
# 2024-12-30 17:41:27,230 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1705807800001&interval=15m&limit=1000&startTime=1704907800001&symbol=BTCUSDT HTTP/1.1" 200 56184
# 2024-12-30 17:41:27,334 - data.fetch - INFO - Fetching data from 2024-01-21 03:30:00.001000 to 2024-01-31 13:30:00.001000.
# 2024-12-30 17:41:27,335 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1705807800001, endTime 1706707800001, limit 1000.
# 2024-12-30 17:41:27,599 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1706707800001&interval=15m&limit=1000&startTime=1705807800001&symbol=BTCUSDT HTTP/1.1" 200 56035
# 2024-12-30 17:41:27,704 - data.fetch - INFO - Fetching data from 2024-01-31 13:30:00.001000 to 2024-02-10 23:30:00.001000.
# 2024-12-30 17:41:27,705 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1706707800001, endTime 1707607800001, limit 1000.
# 2024-12-30 17:41:27,967 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1707607800001&interval=15m&limit=1000&startTime=1706707800001&symbol=BTCUSDT HTTP/1.1" 200 55841
# 2024-12-30 17:41:28,072 - data.fetch - INFO - Fetching data from 2024-02-10 23:30:00.001000 to 2024-02-21 09:30:00.001000.
# 2024-12-30 17:41:28,073 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1707607800001, endTime 1708507800001, limit 1000.
# 2024-12-30 17:41:28,340 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1708507800001&interval=15m&limit=1000&startTime=1707607800001&symbol=BTCUSDT HTTP/1.1" 200 56268
# 2024-12-30 17:41:28,445 - data.fetch - INFO - Fetching data from 2024-02-21 09:30:00.001000 to 2024-03-02 19:30:00.001000.
# 2024-12-30 17:41:28,447 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1708507800001, endTime 1709407800001, limit 1000.
# 2024-12-30 17:41:28,710 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1709407800001&interval=15m&limit=1000&startTime=1708507800001&symbol=BTCUSDT HTTP/1.1" 200 56583
# 2024-12-30 17:41:28,817 - data.fetch - INFO - Fetching data from 2024-03-02 19:30:00.001000 to 2024-03-13 05:30:00.001000.
# 2024-12-30 17:41:28,818 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1709407800001, endTime 1710307800001, limit 1000.
# 2024-12-30 17:41:29,084 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1710307800001&interval=15m&limit=1000&startTime=1709407800001&symbol=BTCUSDT HTTP/1.1" 200 57458
# 2024-12-30 17:41:29,190 - data.fetch - INFO - Fetching data from 2024-03-13 05:30:00.001000 to 2024-03-23 15:30:00.001000.
# 2024-12-30 17:41:29,190 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1710307800001, endTime 1711207800001, limit 1000.
# 2024-12-30 17:41:29,455 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1711207800001&interval=15m&limit=1000&startTime=1710307800001&symbol=BTCUSDT HTTP/1.1" 200 57633
# 2024-12-30 17:41:29,560 - data.fetch - INFO - Fetching data from 2024-03-23 15:30:00.001000 to 2024-04-03 01:30:00.001000.
# 2024-12-30 17:41:29,561 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1711207800001, endTime 1712107800001, limit 1000.
# 2024-12-30 17:41:29,827 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1712107800001&interval=15m&limit=1000&startTime=1711207800001&symbol=BTCUSDT HTTP/1.1" 200 56546
# 2024-12-30 17:41:29,932 - data.fetch - INFO - Fetching data from 2024-04-03 01:30:00.001000 to 2024-04-13 11:30:00.001000.
# 2024-12-30 17:41:29,932 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1712107800001, endTime 1713007800001, limit 1000.
# 2024-12-30 17:41:30,196 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1713007800001&interval=15m&limit=1000&startTime=1712107800001&symbol=BTCUSDT HTTP/1.1" 200 56825
# 2024-12-30 17:41:30,301 - data.fetch - INFO - Fetching data from 2024-04-13 11:30:00.001000 to 2024-04-23 21:30:00.001000.
# 2024-12-30 17:41:30,302 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1713007800001, endTime 1713907800001, limit 1000.
# 2024-12-30 17:41:30,567 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1713907800001&interval=15m&limit=1000&startTime=1713007800001&symbol=BTCUSDT HTTP/1.1" 200 57249
# 2024-12-30 17:41:30,673 - data.fetch - INFO - Fetching data from 2024-04-23 21:30:00.001000 to 2024-05-04 07:30:00.001000.
# 2024-12-30 17:41:30,674 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1713907800001, endTime 1714807800001, limit 1000.
# 2024-12-30 17:41:30,939 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1714807800001&interval=15m&limit=1000&startTime=1713907800001&symbol=BTCUSDT HTTP/1.1" 200 56647
# 2024-12-30 17:41:31,046 - data.fetch - INFO - Fetching data from 2024-05-04 07:30:00.001000 to 2024-05-14 17:30:00.001000.
# 2024-12-30 17:41:31,047 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1714807800001, endTime 1715707800001, limit 1000.
# 2024-12-30 17:41:31,313 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1715707800001&interval=15m&limit=1000&startTime=1714807800001&symbol=BTCUSDT HTTP/1.1" 200 55977
# 2024-12-30 17:41:31,419 - data.fetch - INFO - Fetching data from 2024-05-14 17:30:00.001000 to 2024-05-25 03:30:00.001000.
# 2024-12-30 17:41:31,420 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1715707800001, endTime 1716607800001, limit 1000.
# 2024-12-30 17:41:31,686 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1716607800001&interval=15m&limit=1000&startTime=1715707800001&symbol=BTCUSDT HTTP/1.1" 200 56239
# 2024-12-30 17:41:31,793 - data.fetch - INFO - Fetching data from 2024-05-25 03:30:00.001000 to 2024-06-04 13:30:00.001000.
# 2024-12-30 17:41:31,794 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1716607800001, endTime 1717507800001, limit 1000.
# 2024-12-30 17:41:32,058 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1717507800001&interval=15m&limit=1000&startTime=1716607800001&symbol=BTCUSDT HTTP/1.1" 200 55299
# 2024-12-30 17:41:32,163 - data.fetch - INFO - Fetching data from 2024-06-04 13:30:00.001000 to 2024-06-14 23:30:00.001000.
# 2024-12-30 17:41:32,164 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1717507800001, endTime 1718407800001, limit 1000.
# 2024-12-30 17:41:32,434 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1718407800001&interval=15m&limit=1000&startTime=1717507800001&symbol=BTCUSDT HTTP/1.1" 200 55515
# 2024-12-30 17:41:32,540 - data.fetch - INFO - Fetching data from 2024-06-14 23:30:00.001000 to 2024-06-25 09:30:00.001000.
# 2024-12-30 17:41:32,541 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1718407800001, endTime 1719307800001, limit 1000.
# 2024-12-30 17:41:32,804 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1719307800001&interval=15m&limit=1000&startTime=1718407800001&symbol=BTCUSDT HTTP/1.1" 200 55029
# 2024-12-30 17:41:32,910 - data.fetch - INFO - Fetching data from 2024-06-25 09:30:00.001000 to 2024-07-05 19:30:00.001000.
# 2024-12-30 17:41:32,911 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1719307800001, endTime 1720207800001, limit 1000.
# 2024-12-30 17:41:33,178 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1720207800001&interval=15m&limit=1000&startTime=1719307800001&symbol=BTCUSDT HTTP/1.1" 200 55732
# 2024-12-30 17:41:33,287 - data.fetch - INFO - Fetching data from 2024-07-05 19:30:00.001000 to 2024-07-16 05:30:00.001000.
# 2024-12-30 17:41:33,287 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1720207800001, endTime 1721107800001, limit 1000.
# 2024-12-30 17:41:33,555 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1721107800001&interval=15m&limit=1000&startTime=1720207800001&symbol=BTCUSDT HTTP/1.1" 200 55988
# 2024-12-30 17:41:33,662 - data.fetch - INFO - Fetching data from 2024-07-16 05:30:00.001000 to 2024-07-26 15:30:00.001000.
# 2024-12-30 17:41:33,663 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1721107800001, endTime 1722007800001, limit 1000.
# 2024-12-30 17:41:33,929 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1722007800001&interval=15m&limit=1000&startTime=1721107800001&symbol=BTCUSDT HTTP/1.1" 200 55556
# 2024-12-30 17:41:34,034 - data.fetch - INFO - Fetching data from 2024-07-26 15:30:00.001000 to 2024-08-06 01:30:00.001000.
# 2024-12-30 17:41:34,035 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1722007800001, endTime 1722907800001, limit 1000.
# 2024-12-30 17:41:34,299 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1722907800001&interval=15m&limit=1000&startTime=1722007800001&symbol=BTCUSDT HTTP/1.1" 200 55890
# 2024-12-30 17:41:34,404 - data.fetch - INFO - Fetching data from 2024-08-06 01:30:00.001000 to 2024-08-16 11:30:00.001000.
# 2024-12-30 17:41:34,408 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1722907800001, endTime 1723807800001, limit 1000.
# 2024-12-30 17:41:34,673 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1723807800001&interval=15m&limit=1000&startTime=1722907800001&symbol=BTCUSDT HTTP/1.1" 200 56792
# 2024-12-30 17:41:34,778 - data.fetch - INFO - Fetching data from 2024-08-16 11:30:00.001000 to 2024-08-26 21:30:00.001000.
# 2024-12-30 17:41:34,780 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1723807800001, endTime 1724707800001, limit 1000.
# 2024-12-30 17:41:35,045 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1724707800001&interval=15m&limit=1000&startTime=1723807800001&symbol=BTCUSDT HTTP/1.1" 200 55684
# 2024-12-30 17:41:35,153 - data.fetch - INFO - Fetching data from 2024-08-26 21:30:00.001000 to 2024-09-06 07:30:00.001000.
# 2024-12-30 17:41:35,154 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1724707800001, endTime 1725607800001, limit 1000.
# 2024-12-30 17:41:35,423 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1725607800001&interval=15m&limit=1000&startTime=1724707800001&symbol=BTCUSDT HTTP/1.1" 200 55288
# 2024-12-30 17:41:35,528 - data.fetch - INFO - Fetching data from 2024-09-06 07:30:00.001000 to 2024-09-16 17:30:00.001000.
# 2024-12-30 17:41:35,529 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1725607800001, endTime 1726507800001, limit 1000.
# 2024-12-30 17:41:35,793 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1726507800001&interval=15m&limit=1000&startTime=1725607800001&symbol=BTCUSDT HTTP/1.1" 200 55341
# 2024-12-30 17:41:35,898 - data.fetch - INFO - Fetching data from 2024-09-16 17:30:00.001000 to 2024-09-27 03:30:00.001000.
# 2024-12-30 17:41:35,899 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1726507800001, endTime 1727407800001, limit 1000.
# 2024-12-30 17:41:36,164 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1727407800001&interval=15m&limit=1000&startTime=1726507800001&symbol=BTCUSDT HTTP/1.1" 200 55475
# 2024-12-30 17:41:36,270 - data.fetch - INFO - Fetching data from 2024-09-27 03:30:00.001000 to 2024-10-07 13:30:00.001000.
# 2024-12-30 17:41:36,270 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1727407800001, endTime 1728307800001, limit 1000.
# 2024-12-30 17:41:36,543 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1728307800001&interval=15m&limit=1000&startTime=1727407800001&symbol=BTCUSDT HTTP/1.1" 200 55028
# 2024-12-30 17:41:36,648 - data.fetch - INFO - Fetching data from 2024-10-07 13:30:00.001000 to 2024-10-17 23:30:00.001000.
# 2024-12-30 17:41:36,649 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1728307800001, endTime 1729207800001, limit 1000.
# 2024-12-30 17:41:36,915 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1729207800001&interval=15m&limit=1000&startTime=1728307800001&symbol=BTCUSDT HTTP/1.1" 200 55684
# 2024-12-30 17:41:37,020 - data.fetch - INFO - Fetching data from 2024-10-17 23:30:00.001000 to 2024-10-28 09:30:00.001000.
# 2024-12-30 17:41:37,021 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1729207800001, endTime 1730107800001, limit 1000.
# 2024-12-30 17:41:37,294 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1730107800001&interval=15m&limit=1000&startTime=1729207800001&symbol=BTCUSDT HTTP/1.1" 200 55058
# 2024-12-30 17:41:37,400 - data.fetch - INFO - Fetching data from 2024-10-28 09:30:00.001000 to 2024-11-07 19:30:00.001000.
# 2024-12-30 17:41:37,400 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1730107800001, endTime 1731007800001, limit 1000.
# 2024-12-30 17:41:37,666 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1731007800001&interval=15m&limit=1000&startTime=1730107800001&symbol=BTCUSDT HTTP/1.1" 200 56452
# 2024-12-30 17:41:37,773 - data.fetch - INFO - Fetching data from 2024-11-07 19:30:00.001000 to 2024-11-18 05:30:00.001000.
# 2024-12-30 17:41:37,774 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1731007800001, endTime 1731907800001, limit 1000.
# 2024-12-30 17:41:38,042 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1731907800001&interval=15m&limit=1000&startTime=1731007800001&symbol=BTCUSDT HTTP/1.1" 200 57408
# 2024-12-30 17:41:38,150 - data.fetch - INFO - Fetching data from 2024-11-18 05:30:00.001000 to 2024-11-28 15:30:00.001000.
# 2024-12-30 17:41:38,151 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1731907800001, endTime 1732807800001, limit 1000.
# 2024-12-30 17:41:38,414 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1732807800001&interval=15m&limit=1000&startTime=1731907800001&symbol=BTCUSDT HTTP/1.1" 200 57463
# 2024-12-30 17:41:38,521 - data.fetch - INFO - Fetching data from 2024-11-28 15:30:00.001000 to 2024-12-09 01:30:00.001000.
# 2024-12-30 17:41:38,522 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1732807800001, endTime 1733707800001, limit 1000.
# 2024-12-30 17:41:38,788 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1733707800001&interval=15m&limit=1000&startTime=1732807800001&symbol=BTCUSDT HTTP/1.1" 200 56898
# 2024-12-30 17:41:38,894 - data.fetch - INFO - Fetching data from 2024-12-09 01:30:00.001000 to 2024-12-19 11:30:00.001000.
# 2024-12-30 17:41:38,898 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1733707800001, endTime 1734607800001, limit 1000.
# 2024-12-30 17:41:39,164 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1734607800001&interval=15m&limit=1000&startTime=1733707800001&symbol=BTCUSDT HTTP/1.1" 200 57577
# 2024-12-30 17:41:39,269 - data.fetch - INFO - Fetching data from 2024-12-19 11:30:00.001000 to 2024-12-29 21:30:00.001000.
# 2024-12-30 17:41:39,270 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1734607800001, endTime 1735507800001, limit 1000.
# 2024-12-30 17:41:39,534 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1735507800001&interval=15m&limit=1000&startTime=1734607800001&symbol=BTCUSDT HTTP/1.1" 200 56971
# 2024-12-30 17:41:39,642 - data.fetch - INFO - Fetching data from 2024-12-29 21:30:00.001000 to 2024-12-30 17:41:13.233000.
# 2024-12-30 17:41:39,643 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1735507800001, endTime 1735580473233, limit 1000.
# 2024-12-30 17:41:39,904 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1735580473233&interval=15m&limit=1000&startTime=1735507800001&symbol=BTCUSDT HTTP/1.1" 200 4550
# 2024-12-30 17:41:40,006 - data.fetch - INFO - Fetching data from 2024-12-30 17:30:00.001000 to 2024-12-30 17:41:13.233000.
# 2024-12-30 17:41:40,007 - data.fetch - INFO - Fetching candlestick data for BTCUSDT with interval 15m, startTime 1735579800001, endTime 1735580473233, limit 1000.
# 2024-12-30 17:41:40,259 - urllib3.connectionpool - DEBUG - https://api.binance.com:443 "GET /api/v3/klines?endTime=1735580473233&interval=15m&limit=1000&startTime=1735579800001&symbol=BTCUSDT HTTP/1.1" 200 2
# 2024-12-30 17:41:40,260 - data.fetch - WARNING - No more data returned for time range: 2024-12-30 17:30:00.001000 to 2024-12-30 17:41:13.233000.
# 2024-12-30 17:41:40,261 - data.fetch - INFO - Fetched 70075 rows. Saving data to BTCUSDT_15m_day730_day0.csv.
# 2024-12-30 17:41:40,743 - data.fetch - INFO - Data saved successfully to BTCUSDT_15m_day730_day0.csv.
# Data successfully saved to BTCUSDT_15m_day730_day0.csv

# %%
print(f"Start Time (ms): {start_days_ago}, {datetime.fromtimestamp(start_days_ago / 1000)}")
print(f"End Time (ms): {end_days_ago}, {datetime.fromtimestamp(end_days_ago / 1000)}")

# %%
import importlib
import data.fetch  # Replace 'fetch' with the module name
importlib.reload(data.fetch)

# %%
# Initialize the options fetcher
options_fetcher = BinanceOptionsFetcher(api_key=BINANCE_API_KEY, api_secret=BINANCE_SECRET_KEY)

# Define the option symbol
option_symbol = "BTC-250328-90000-P"  # Replace with a valid symbol if necessary

# Fetch and print option info
print(f"Fetching option info for {option_symbol}...")

try:
    option_info = options_fetcher.get_option_info(option_symbol)
    print("Option Info Retrieved Successfully:")
    print(option_info)
except Exception as e:
    print(f"Error fetching option info: {e}")

# Get current price
current_price = options_fetcher.get_current_option_price(option_symbol)
print(f"Current Price: {current_price}")

# Get historical klines
klines = options_fetcher.get_historical_option_klines(option_symbol, interval="1h", limit=50)
print(f"Historical Klines: {klines}")

# Get recent trades
recent_trades = options_fetcher.get_recent_option_trades(option_symbol, limit=5)
print(f"Recent Trades: {recent_trades}")
